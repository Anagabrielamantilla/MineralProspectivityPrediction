# %%
# Elaborado por:
# Ana Mantilla : anagmd2019@gmail.com
# Paul Goyes : goyes.yesid@gmail.com

# %%
# !git clone https://github.com/Anagabrielamantilla/MineralPrediction.git
# Out:
# Cloning into 'MineralPrediction'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 172 (delta 41), reused 0 (delta 0), pack-reused 96
# Receiving objects: 100% (172/172), 12.66 MiB | 14.03 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %% [markdown]
# # **01. Cargar los datos**

# %%
import pandas as pd

# %%
# df = pd.read_csv('/content/MineralPrediction/Data/00_Training.csv')

# %%
df.shape
# Out:
# (148, 11)

# %%
df.head()

# %%
# Verificar que no haya valores nulos y en caso de que sí, eliminarlos
# df.shape debe ser igual a training.shape en caso de que no existan valores null

training = df.dropna()
training.shape
# Out:
# (148, 11)

# %% [markdown]
# # **02. Matriz de correlación**

# %%
columns = ['X1','X2','X3','X4','X5','X6','X7','X8','X9','X10','X11']
X = df[columns]

# %%
X

# %%
# Estandarización de las variables 

from sklearn.preprocessing import StandardScaler

XX=df[columns].values
x = StandardScaler().fit_transform(XX)

# %%
# Llevar x (np) a un df

X2=pd.DataFrame(data=x,columns=columns)

# %%
import matplotlib.pyplot as plt
import seaborn as sn 

corrMatrix = X.corr()
sn.set(rc = {'figure.figsize':(14,11)}, font_scale=1.1)
sn.heatmap(corrMatrix, annot=True,cmap="jet", alpha= 1)
